# %%
import dspy
import json
from typing import List, Dict, Optional

# The system prompt is implicitly handled by the DSPy Signature's docstring.
# We define the desired input and output fields for the model.
class Graph(dspy.Signature):
    """
    You are a network graph maker who extracts terms and their relations from a given context.
    Extract the ontology of terms mentioned in the context. These terms should represent the key concepts.
    Terms may include objects, entities, locations, organizations, persons, conditions, acronyms, documents, services, or concepts.
    Terms should be as atomistic as possible.
    Think about how these terms can have one-on-one relations with other terms mentioned in the same sentence or paragraph.
    Find the relation between each such related pair of terms.

    Format your output as a list of JSON objects. Each element of the list contains a pair of terms
    and the relation between them.
    """
    
    context = dspy.InputField(
        desc="The context chunk from which to extract the graph."
    )
    graph_json = dspy.OutputField(
        desc="A list of json objects, like the following: "
             '[{"node_1": "A concept", "node_2": "A related concept", "edge": "relationship between the two concepts"}]'
    )

def construct_graph_from_text(text: str, llm: dspy.LM) -> Optional[List[Dict[str, str]]]:
    """
    Constructs a network graph in JSON format from text using an Ollama LLM with DSPy.

    Args:
        text (str): The input text to process.
        llm (dspy.LM): An initialized DSPy language model (e.g., dspy.OllamaLocal).

    Returns:
        Optional[List[Dict[str, str]]]: A list of dictionaries representing the graph,
                                         or None if validation fails.
    """
    # Configure DSPy to use the provided language model.
    dspy.settings.configure(lm=llm)

    # Define the generator module with a ChainOfThought pattern.
    generator = dspy.ChainOfThought(Graph)
    
    # Run the model to get the result.
    result = generator(context=text)

    try:
        # The output from the model is a string that needs to be parsed into JSON.
        graph_data = json.loads(result.graph_json)

        # Basic validation to ensure the output is a list of dictionaries
        # with the required keys.
        if not isinstance(graph_data, list):
            print("Validation Error: Output is not a list.")
            return None

        for item in graph_data:
            if not isinstance(item, dict) or not all(key in item for key in ["node_1", "node_2", "edge"]):
                print(f"Validation Error: Item '{item}' is missing required keys.")
                return None
        
        return graph_data

    except (json.JSONDecodeError, TypeError) as e:
        print(f"Error decoding or validating JSON: {e}")
        return None

# %%
try:
    ## Mistral try?
    ollama_lm = dspy.LM('ollama_chat/deepseek-r1:32b', api_base='http://localhost:11434', api_key='')
except Exception as e:
    print(f"Failed to initialize Ollama. Please ensure Ollama is running and accessible.")
    print(f"Error: {e}")
    ollama_lm = None

# %%
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine
from mimic.orm_create.mimiciv_v3_orm import PreprocessedRevisedNote, Base

DB_URI = "postgresql://postgres:password@localhost:5432/mimicIV_v3"
engine = create_engine(DB_URI)
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()
discharge_notes = session.query(PreprocessedRevisedNote).all()

# %%
discharge_notes[0].text
# Out:
# ' \n                        Unit    \n \n Admission Date                 Discharge Date    \n \n Date Birth                sex    F \n \n Service MEDICINE \n \n Allergies \n Known Allergies Adverse Drug reaction \n \n attending \n \n Chief Complaint \n worsen ABD distension pain \n \n history Present Illness \n hcv cirrhosis c b ascite hiv ART h o IVDU COPD \n bioplar ptsd present OSH ED worsen abd \n distension past week  \n Pt report self discontinue lasix spirnolactone week \n ago feel like \n want chemical \n follow na restrict diet past week note \n have worsen abd distension discomfort \n deny edema SOB orthopnea deny f c n v d c \n dysuria food poisoning week ago eat stale \n cake n v 20 min food ingestion resolve \n day deny recent illness sick contact note \n notice gum bleed brush tooth \n recent week deny easy bruising melena BRBPR \n hemetesis hemoptysis hematuria  \n abd pain go OSH ED transfer \n care ED report pt brief period \n confusion recall ultrasound bloodwork \n osh deny recent drug use alcohol use deny \n feel confused report forgetful time  \n ED initial vital 98.4 70 106/63 16 97%RA  \n Labs notable ALT AST AP \n tbili1.6 WBC 5 K platelet 77 INR 1.6  \n\n \n Past Medical History \n 1 HCV Cirrhosis  \n 2 history abnormal pap smear  \n 3 calcification breast remove  \n previously patient benign  \n 4 HIV disease follow Dr. Dr.  \n  \n 5 copd  \n 6 past history smoking  \n 7 skin lesion biopsie show  \n skin cancer patient report schedule complete  \n removal skin lesion year  \n 8 lesion forehead purple  \n discoloration biopsie exclude possibility  \n sarcoma result pende  \n 9 15 mm hypoechoic lesion ultrasound  \n monitor MRI  \n 10 history dysplasia anus  \n 11 bipolar affective disorder currently manic mild ptsd \n \n 12 history cocaine heroin use  \n\n \n Social History \n \n Physical Exam \n VS 98.1 107/61 78 18 97ra  \n General NAD  \n HEENT CTAB anicteric sclera op clear  \n neck supple LAD  \n CV RRR S1S2 m r g  \n lung CTAb prolonged expiratory phase w r r  \n Abdomen distend mild diffuse tenderness + flank dullness \n percuss liver spleen edge distension  \n GU foley  \n ext wwp c e e + club  \n Neuro AAO3 converse normally able recall 3 time 5 \n minute CN II XII intact  \n\n'

# %%
import json
from tqdm import tqdm
import os

os.makedirs("revised_preprocessed_kgs", exist_ok=True)
failed = 0
for i in tqdm(range(len(discharge_notes))):
    if os.path.exists(f"revised_preprocessed_kgs/{discharge_notes[i].row_id}.json"): continue
    input_text = discharge_notes[i].text
    json_graph_output = construct_graph_from_text(input_text, ollama_lm)
    
    # Print the validated JSON output.
    if json_graph_output:
        json_ouput = json.dumps(json_graph_output, indent=4)
        with open(f"revised_preprocessed_kgs/{discharge_notes[i].row_id}.json", 'w') as f:
            f.write(json_ouput)
    else:
        failed += 1
        print(f"Could not generate or validate the graph from the provided text. Overall failed: {failed}")
# Out:
#   0%|          | 56/331793 [15:04<2491:49:23, 27.04s/it]
# Validation Error: Item '{'node_2': 'HTN', 'edge': 'related to'}' is missing required keys.
# Could not generate or validate the graph from the provided text. Overall failed: 1
#   0%|          | 114/331793 [1:12:05<5498:06:17, 59.68s/it]
# Validation Error: Item '{'node_1': 'Blood culture', 'edge': 'test performed'}' is missing required keys.
# Could not generate or validate the graph from the provided text. Overall failed: 2
#   0%|          | 148/331793 [1:43:06<5614:19:05, 60.94s/it]2025/06/30 17:12:13 WARNING dspy.adapters.json_adapter: Failed to use structured output format, falling back to JSON mode.
#   0%|          | 148/331793 [1:44:55<3918:22:24, 42.53s/it]
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~\git\KARDIA\.venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:171, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     170 try:
# --> 171     response = sync_httpx_client.post(
#     172         url=api_base,
#     173         headers=headers,
#     174         data=(
#     175             signed_json_body
#     176             if signed_json_body is not None
#     177             else json.dumps(data)
#     178         ),
#     179         timeout=timeout,
#     180         stream=stream,
#     181         logging_obj=logging_obj,
#     182     )
#     183 except httpx.HTTPStatusError as e:
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:756, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     755 except Exception as e:
# --> 756     raise e
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:735, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     732     req = self.client.build_request(
#     733         "POST", url, data=data, json=json, params=params, headers=headers, files=files, content=content  # type: ignore
#     734     )
# --> 735 response = self.client.send(req, stream=stream)
#     736 response.raise_for_status()
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~\git\KARDIA\.venv\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# During handling of the above exception, another exception occurred:
#
# OllamaError                               Traceback (most recent call last)
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\main.py:3031, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3024     api_key = (
#    3025         api_key
#    3026         or litellm.ollama_key
#    3027         or os.environ.get("OLLAMA_API_KEY")
#    3028         or litellm.api_key
#    3029     )
# -> 3031     response = base_llm_http_handler.completion(
#    3032         model=model,
#    3033         stream=stream,
#    3034         messages=messages,
#    3035         acompletion=acompletion,
#    3036         api_base=api_base,
#    3037         model_response=model_response,
#    3038         optional_params=optional_params,
#    3039         litellm_params=litellm_params,
#    3040         custom_llm_provider="ollama_chat",
#    3041         timeout=timeout,
#    3042         headers=headers,
#    3043         encoding=encoding,
#    3044         api_key=api_key,
#    3045         logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    3046         client=client,
#    3047     )
#    3049 elif custom_llm_provider == "triton":
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:466, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config)
#     464     sync_httpx_client = client
# --> 466 response = self._make_common_sync_call(
#     467     sync_httpx_client=sync_httpx_client,
#     468     provider_config=provider_config,
#     469     api_base=api_base,
#     470     headers=headers,
#     471     data=data,
#     472     signed_json_body=signed_json_body,
#     473     timeout=timeout,
#     474     litellm_params=litellm_params,
#     475     logging_obj=logging_obj,
#     476 )
#     477 return provider_config.transform_response(
#     478     model=model,
#     479     raw_response=response,
#    (...)    488     json_mode=json_mode,
#     489 )
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:198, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     197 except Exception as e:
# --> 198     raise self._handle_error(e=e, provider_config=provider_config)
#     199 break
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:2396, in BaseLLMHTTPHandler._handle_error(self, e, provider_config)
#    2390     raise BaseLLMException(
#    2391         status_code=status_code,
#    2392         message=error_text,
#    2393         headers=error_headers,
#    2394     )
# -> 2396 raise provider_config.get_error_class(
#    2397     error_message=error_text,
#    2398     status_code=status_code,
#    2399     headers=error_headers,
#    2400 )
#
# OllamaError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\utils.py:1179, in client.<locals>.wrapper(*args, **kwargs)
#    1178 # MODEL CALL
# -> 1179 result = original_function(*args, **kwargs)
#    1180 end_time = datetime.datetime.now()
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\main.py:3311, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3309 except Exception as e:
#    3310     ## Map to OpenAI Exception
# -> 3311     raise exception_type(
#    3312         model=model,
#    3313         custom_llm_provider=custom_llm_provider,
#    3314         original_exception=e,
#    3315         completion_kwargs=args,
#    3316         extra_kwargs=kwargs,
#    3317     )
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2284, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2283     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2284     raise e
#    2285 else:
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2253, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2252 if hasattr(original_exception, "request"):
# -> 2253     raise APIConnectionError(
#    2254         message="{} - {}".format(exception_provider, error_str),
#    2255         llm_provider=custom_llm_provider,
#    2256         model=model,
#    2257         request=original_exception.request,
#    2258     )
#    2259 else:
#
# APIConnectionError: litellm.APIConnectionError: Ollama_chatException - [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\adapters\json_adapter.py:69, in JSONAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      68     lm_kwargs["response_format"] = {"type": "json_object"}
# ---> 69     return super().__call__(lm, lm_kwargs, signature, demos, inputs)
#      70 except AdapterParseError as e:
#      71     # On AdapterParseError, we raise the original error.
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\adapters\chat_adapter.py:50, in ChatAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      47 if isinstance(e, ContextWindowExceededError) or isinstance(self, JSONAdapter):
#      48     # On context window exceeded error or already using JSONAdapter, we don't want to retry with a different
#      49     # adapter.
# ---> 50     raise e
#      51 return JSONAdapter()(lm, lm_kwargs, signature, demos, inputs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\adapters\chat_adapter.py:42, in ChatAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      41 try:
# ---> 42     return super().__call__(lm, lm_kwargs, signature, demos, inputs)
#      43 except Exception as e:
#      44     # fallback to JSONAdapter
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\adapters\base.py:119, in Adapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#     117 inputs = self.format(processed_signature, demos, inputs)
# --> 119 outputs = lm(messages=inputs, **lm_kwargs)
#     120 return self._call_postprocess(signature, outputs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\utils\callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\clients\base_lm.py:96, in BaseLM.__call__(self, prompt, messages, **kwargs)
#      94 @with_callbacks
#      95 def __call__(self, prompt=None, messages=None, **kwargs):
# ---> 96     response = self.forward(prompt=prompt, messages=messages, **kwargs)
#      97     outputs = self._process_lm_response(response, prompt, messages, **kwargs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\clients\lm.py:127, in LM.forward(self, prompt, messages, **kwargs)
#     125 completion, litellm_cache_args = self._get_cached_completion_fn(completion, cache, enable_memory_cache)
# --> 127 results = completion(
#     128     request=dict(model=self.model, messages=messages, **kwargs),
#     129     num_retries=self.num_retries,
#     130     cache=litellm_cache_args,
#     131 )
#     133 if any(c.finish_reason == "length" for c in results["choices"]):
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\clients\cache.py:232, in request_cache.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#     231 # Otherwise, compute and store the result
# --> 232 result = fn(*args, **kwargs)
#     233 # `enable_memory_cache` can be provided at call time to avoid indefinite growth.
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\clients\lm.py:304, in litellm_completion(request, num_retries, cache)
#     303 if stream_completion is None:
# --> 304     return litellm.completion(
#     305         cache=cache,
#     306         num_retries=num_retries,
#     307         retry_strategy="exponential_backoff_retry",
#     308         **request,
#     309     )
#     311 return stream_completion()
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\utils.py:1284, in client.<locals>.wrapper(*args, **kwargs)
#    1283         kwargs["num_retries"] = num_retries
# -> 1284         return litellm.completion_with_retries(*args, **kwargs)
#    1285 elif (
#    1286     isinstance(e, litellm.exceptions.ContextWindowExceededError)
#    1287     and context_window_fallback_dict
#    1288     and model in context_window_fallback_dict
#    1289     and not _is_litellm_router_call
#    1290 ):
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\main.py:3349, in completion_with_retries(*args, **kwargs)
#    3346     retryer = tenacity.Retrying(
#    3347         stop=tenacity.stop_after_attempt(num_retries), reraise=True
#    3348     )
# -> 3349 return retryer(original_function, *args, **kwargs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File ~\git\KARDIA\.venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~\git\KARDIA\.venv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~\git\KARDIA\.venv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~\git\KARDIA\.venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\utils.py:1304, in client.<locals>.wrapper(*args, **kwargs)
#    1301     logging_obj.failure_handler(
#    1302         e, traceback_exception, start_time, end_time
#    1303     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1304 raise e
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\utils.py:1179, in client.<locals>.wrapper(*args, **kwargs)
#    1178 # MODEL CALL
# -> 1179 result = original_function(*args, **kwargs)
#    1180 end_time = datetime.datetime.now()
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\main.py:3311, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3309 except Exception as e:
#    3310     ## Map to OpenAI Exception
# -> 3311     raise exception_type(
#    3312         model=model,
#    3313         custom_llm_provider=custom_llm_provider,
#    3314         original_exception=e,
#    3315         completion_kwargs=args,
#    3316         extra_kwargs=kwargs,
#    3317     )
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2284, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2283     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2284     raise e
#    2285 else:
#
# File ~\git\KARDIA\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2253, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2252 if hasattr(original_exception, "request"):
# -> 2253     raise APIConnectionError(
#    2254         message="{} - {}".format(exception_provider, error_str),
#    2255         llm_provider=custom_llm_provider,
#    2256         model=model,
#    2257         request=original_exception.request,
#    2258     )
#    2259 else:
#
# APIConnectionError: litellm.APIConnectionError: Ollama_chatException - [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 10
#       8 if os.path.exists(f"revised_preprocessed_kgs/{discharge_notes[i].row_id}.json"): continue
#       9 input_text = discharge_notes[i].text
# ---> 10 json_graph_output = construct_graph_from_text(input_text, ollama_lm)
#      12 # Print the validated JSON output.
#      13 if json_graph_output:
#
# Cell In[13], line 47, in construct_graph_from_text(text, llm)
#      44 generator = dspy.ChainOfThought(Graph)
#      46 # Run the model to get the result.
# ---> 47 result = generator(context=text)
#      49 try:
#      50     # The output from the model is a string that needs to be parsed into JSON.
#      51     graph_data = json.loads(result.graph_json)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\utils\callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\primitives\program.py:60, in Module.__call__(self, *args, **kwargs)
#      57     output.set_lm_usage(usage_tracker.get_total_tokens())
#      58     return output
# ---> 60 return self.forward(*args, **kwargs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\predict\chain_of_thought.py:38, in ChainOfThought.forward(self, **kwargs)
#      37 def forward(self, **kwargs):
# ---> 38     return self.predict(**kwargs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\predict\predict.py:85, in Predict.__call__(self, *args, **kwargs)
#      82 if args:
#      83     raise ValueError(self._get_positional_args_error_message())
# ---> 85 return super().__call__(**kwargs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\utils\callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\primitives\program.py:60, in Module.__call__(self, *args, **kwargs)
#      57     output.set_lm_usage(usage_tracker.get_total_tokens())
#      58     return output
# ---> 60 return self.forward(*args, **kwargs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\predict\predict.py:157, in Predict.forward(self, **kwargs)
#     155 else:
#     156     with settings.context(send_stream=None):
# --> 157         completions = adapter(lm, lm_kwargs=config, signature=signature, demos=demos, inputs=kwargs)
#     159 return self._forward_postprocess(completions, signature, **kwargs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\adapters\chat_adapter.py:51, in ChatAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      47 if isinstance(e, ContextWindowExceededError) or isinstance(self, JSONAdapter):
#      48     # On context window exceeded error or already using JSONAdapter, we don't want to retry with a different
#      49     # adapter.
#      50     raise e
# ---> 51 return JSONAdapter()(lm, lm_kwargs, signature, demos, inputs)
#
# File ~\git\KARDIA\.venv\Lib\site-packages\dspy\adapters\json_adapter.py:75, in JSONAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      72     raise e
#      73 except Exception as e:
#      74     # On any other error, we raise a RuntimeError with the original error message.
# ---> 75     raise RuntimeError(
#      76         "Both structured output format and JSON mode failed. Please choose a model that supports "
#      77         f"`response_format` argument. Original error: {e}"
#      78     ) from e
#
# RuntimeError: Both structured output format and JSON mode failed. Please choose a model that supports `response_format` argument. Original error: litellm.APIConnectionError: Ollama_chatException - [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
